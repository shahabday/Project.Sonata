# %% [markdown]
# <a href="https://colab.research.google.com/github/shahabday/Project.Sonata/blob/main/first_gpt_2_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install torch transformers datasets miditok pretty_midi
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Collecting datasets
#   Downloading datasets-3.3.1-py3-none-any.whl.metadata (19 kB)
# Collecting miditok
#   Downloading miditok-3.0.5.post1-py3-none-any.whl.metadata (10 kB)
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.10.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 27.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.12)
# Collecting symusic>=0.5.0 (from miditok)
#   Downloading symusic-0.5.6-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting mido>=1.1.16 (from pretty_midi)
#   Downloading mido-1.3.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pretty_midi) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Collecting pySmartDL (from symusic>=0.5.0->miditok)
#   Downloading pySmartDL-1.3.4-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from symusic>=0.5.0->miditok) (4.3.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 25.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 24.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 45.1 MB/s eta 0:00:00
# Downloading datasets-3.3.1-py3-none-any.whl (484 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 2.7 MB/s eta 0:00:00
# Downloading miditok-3.0.5.post1-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.1 MB/s eta 0:00:00
# Downloading mido-1.3.3-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 2.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.7 MB/s eta 0:00:00
# Downloading symusic-0.5.6-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 52.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 12.5 MB/s eta 0:00:00
# Downloading pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Building wheels for collected packages: pretty_midi
#   Building wheel for pretty_midi (setup.py) ... done
#   Created wheel for pretty_midi: filename=pretty_midi-0.2.10-py3-none-any.whl size=5592287 sha256=a1dd78647dc8e04c9a43ec1d32ec40538fadba030a75d7db33b65b6ca429b841
#   Stored in directory: /root/.cache/pip/wheels/e6/95/ac/15ceaeb2823b04d8e638fd1495357adb8d26c00ccac9d7782e
# Successfully built pretty_midi
# Installing collected packages: pySmartDL, xxhash, symusic, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mido, dill, pretty_midi, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, miditok, datasets
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed datasets-3.3.1 dill-0.3.8 miditok-3.0.5.post1 mido-1.3.3 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pretty_midi-0.2.10 pySmartDL-1.3.4 symusic-0.5.6 xxhash-3.5.0

# %%
# !pip install miditoolkit
# Out:
# Collecting miditoolkit
#   Downloading miditoolkit-1.0.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from miditoolkit) (3.10.0)
# Requirement already satisfied: mido>=1.1.16 in /usr/local/lib/python3.11/dist-packages (from miditoolkit) (1.3.3)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.11/dist-packages (from miditoolkit) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mido>=1.1.16->miditoolkit) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->miditoolkit) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->miditoolkit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->miditoolkit) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->miditoolkit) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->miditoolkit) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->miditoolkit) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->miditoolkit) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->miditoolkit) (1.17.0)
# Downloading miditoolkit-1.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: miditoolkit
# Successfully installed miditoolkit-1.0.1

# %%
import os
from datasets import load_dataset
from datasets import Dataset
import pandas as pd

import miditok
import miditoolkit
from transformers import AutoTokenizer
from transformers import GPT2LMHeadModel
import os
import pandas as pd
import miditok
import miditoolkit
from tqdm import tqdm

# %% [markdown]
# # Download Dataset

# %%
# Step 1: Create Directory for MIDI Files
os.makedirs("maestro_midi", exist_ok=True)

# Step 2: Download the dataset (ZIP format)
maestro_url = "https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip"
zip_path = "maestro_midi.zip"

print("Downloading Maestro MIDI dataset...")
os.system(f"wget {maestro_url} -O {zip_path}")

# Step 3: Extract only MIDI files
print("Extracting MIDI files...")
os.system("unzip -j maestro_midi.zip '*.midi' -d maestro_midi")

# Step 4: Clean up (Optional)
os.remove(zip_path)

print("Download and extraction complete! MIDI files are in 'maestro_midi' directory.")
# Out:
# Downloading Maestro MIDI dataset...
# Extracting MIDI files...
# Download and extraction complete! MIDI files are in 'maestro_midi' directory.

# %%
# Step 1: Create Directory for MIDI Files and Metadata
os.makedirs("maestro_dataset", exist_ok=True)

# Step 2: Download Metadata CSV
metadata_url = "https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0.csv"
metadata_path = "maestro_dataset/maestro_metadata.csv"

print("Downloading Maestro metadata...")
os.system(f"wget {metadata_url} -O {metadata_path}")

# Step 3: Load Metadata
metadata_df = pd.read_csv(metadata_path)
# Out:
# Downloading Maestro metadata...

# %%
len(midi_files)
# Out:
# 1276

# %%
metadata_df["midi_filename"][0]
# Out:
# '2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1.midi'

# %%
metadata_df["filename"] = metadata_df["midi_filename"].str[5:]

# %% [markdown]
# # Tokenizing Midi

# %%
#/content/maestro_midi/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--3.midi

# %%
def get_midi_path(index):
  return os.path.join("/content","maestro_midi",metadata_df["filename"][index])

# %%
get_midi_path(1)
# Out:
# '/content/maestro_midi/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MID--AUDIO_03_R2_2008_wav--2.midi'

# %%
import miditok
import miditoolkit

# Initialize tokenizer
tokenizer = miditok.REMI()

# Load MIDI file
midi_file = get_midi_path(1)

tokens = tokenizer(midi_file)

# %%
tokenizer.vocab
# Out:
# {'PAD_None': 0,
#  'BOS_None': 1,
#  'EOS_None': 2,
#  'MASK_None': 3,
#  'Bar_None': 4,
#  'Pitch_21': 5,
#  'Pitch_22': 6,
#  'Pitch_23': 7,
#  'Pitch_24': 8,
#  'Pitch_25': 9,
#  'Pitch_26': 10,
#  'Pitch_27': 11,
#  'Pitch_28': 12,
#  'Pitch_29': 13,
#  'Pitch_30': 14,
#  'Pitch_31': 15,
#  'Pitch_32': 16,
#  'Pitch_33': 17,
#  'Pitch_34': 18,
#  'Pitch_35': 19,
#  'Pitch_36': 20,
#  'Pitch_37': 21,
#  'Pitch_38': 22,
#  'Pitch_39': 23,
#  'Pitch_40': 24,
#  'Pitch_41': 25,
#  'Pitch_42': 26,
#  'Pitch_43': 27,
#  'Pitch_44': 28,
#  'Pitch_45': 29,
#  'Pitch_46': 30,
#  'Pitch_47': 31,
#  'Pitch_48': 32,
#  'Pitch_49': 33,
#  'Pitch_50': 34,
#  'Pitch_51': 35,
#  'Pitch_52': 36,
#  'Pitch_53': 37,
#  'Pitch_54': 38,
#  'Pitch_55': 39,
#  'Pitch_56': 40,
#  'Pitch_57': 41,
#  'Pitch_58': 42,
#  'Pitch_59': 43,
#  'Pitch_60': 44,
#  'Pitch_61': 45,
#  'Pitch_62': 46,
#  'Pitch_63': 47,
#  'Pitch_64': 48,
#  'Pitch_65': 49,
#  'Pitch_66': 50,
#  'Pitch_67': 51,
#  'Pitch_68': 52,
#  'Pitch_69': 53,
#  'Pitch_70': 54,
#  'Pitch_71': 55,
#  'Pitch_72': 56,
#  'Pitch_73': 57,
#  'Pitch_74': 58,
#  'Pitch_75': 59,
#  'Pitch_76': 60,
#  'Pitch_77': 61,
#  'Pitch_78': 62,
#  'Pitch_79': 63,
#  'Pitch_80': 64,
#  'Pitch_81': 65,
#  'Pitch_82': 66,
#  'Pitch_83': 67,
#  'Pitch_84': 68,
#  'Pitch_85': 69,
#  'Pitch_86': 70,
#  'Pitch_87': 71,
#  'Pitch_88': 72,
#  'Pitch_89': 73,
#  'Pitch_90': 74,
#  'Pitch_91': 75,
#  'Pitch_92': 76,
#  'Pitch_93': 77,
#  'Pitch_94': 78,
#  'Pitch_95': 79,
#  'Pitch_96': 80,
#  'Pitch_97': 81,
#  'Pitch_98': 82,
#  'Pitch_99': 83,
#  'Pitch_100': 84,
#  'Pitch_101': 85,
#  'Pitch_102': 86,
#  'Pitch_103': 87,
#  'Pitch_104': 88,
#  'Pitch_105': 89,
#  'Pitch_106': 90,
#  'Pitch_107': 91,
#  'Pitch_108': 92,
#  'Velocity_3': 93,
#  'Velocity_7': 94,
#  'Velocity_11': 95,
#  'Velocity_15': 96,
#  'Velocity_19': 97,
#  'Velocity_23': 98,
#  'Velocity_27': 99,
#  'Velocity_31': 100,
#  'Velocity_35': 101,
#  'Velocity_39': 102,
#  'Velocity_43': 103,
#  'Velocity_47': 104,
#  'Velocity_51': 105,
#  'Velocity_55': 106,
#  'Velocity_59': 107,
#  'Velocity_63': 108,
#  'Velocity_67': 109,
#  'Velocity_71': 110,
#  'Velocity_75': 111,
#  'Velocity_79': 112,
#  'Velocity_83': 113,
#  'Velocity_87': 114,
#  'Velocity_91': 115,
#  'Velocity_95': 116,
#  'Velocity_99': 117,
#  'Velocity_103': 118,
#  'Velocity_107': 119,
#  'Velocity_111': 120,
#  'Velocity_115': 121,
#  'Velocity_119': 122,
#  'Velocity_123': 123,
#  'Velocity_127': 124,
#  'Duration_0.1.8': 125,
#  'Duration_0.2.8': 126,
#  'Duration_0.3.8': 127,
#  'Duration_0.4.8': 128,
#  'Duration_0.5.8': 129,
#  'Duration_0.6.8': 130,
#  'Duration_0.7.8': 131,
#  'Duration_1.0.8': 132,
#  'Duration_1.1.8': 133,
#  'Duration_1.2.8': 134,
#  'Duration_1.3.8': 135,
#  'Duration_1.4.8': 136,
#  'Duration_1.5.8': 137,
#  'Duration_1.6.8': 138,
#  'Duration_1.7.8': 139,
#  'Duration_2.0.8': 140,
#  'Duration_2.1.8': 141,
#  'Duration_2.2.8': 142,
#  'Duration_2.3.8': 143,
#  'Duration_2.4.8': 144,
#  'Duration_2.5.8': 145,
#  'Duration_2.6.8': 146,
#  'Duration_2.7.8': 147,
#  'Duration_3.0.8': 148,
#  'Duration_3.1.8': 149,
#  'Duration_3.2.8': 150,
#  'Duration_3.3.8': 151,
#  'Duration_3.4.8': 152,
#  'Duration_3.5.8': 153,
#  'Duration_3.6.8': 154,
#  'Duration_3.7.8': 155,
#  'Duration_4.0.4': 156,
#  'Duration_4.1.4': 157,
#  'Duration_4.2.4': 158,
#  'Duration_4.3.4': 159,
#  'Duration_5.0.4': 160,
#  'Duration_5.1.4': 161,
#  'Duration_5.2.4': 162,
#  'Duration_5.3.4': 163,
#  'Duration_6.0.4': 164,
#  'Duration_6.1.4': 165,
#  'Duration_6.2.4': 166,
#  'Duration_6.3.4': 167,
#  'Duration_7.0.4': 168,
#  'Duration_7.1.4': 169,
#  'Duration_7.2.4': 170,
#  'Duration_7.3.4': 171,
#  'Duration_8.0.4': 172,
#  'Duration_8.1.4': 173,
#  'Duration_8.2.4': 174,
#  'Duration_8.3.4': 175,
#  'Duration_9.0.4': 176,
#  'Duration_9.1.4': 177,
#  'Duration_9.2.4': 178,
#  'Duration_9.3.4': 179,
#  'Duration_10.0.4': 180,
#  'Duration_10.1.4': 181,
#  'Duration_10.2.4': 182,
#  'Duration_10.3.4': 183,
#  'Duration_11.0.4': 184,
#  'Duration_11.1.4': 185,
#  'Duration_11.2.4': 186,
#  'Duration_11.3.4': 187,
#  'Duration_12.0.4': 188,
#  'Position_0': 189,
#  'Position_1': 190,
#  'Position_2': 191,
#  'Position_3': 192,
#  'Position_4': 193,
#  'Position_5': 194,
#  'Position_6': 195,
#  'Position_7': 196,
#  'Position_8': 197,
#  'Position_9': 198,
#  'Position_10': 199,
#  'Position_11': 200,
#  'Position_12': 201,
#  'Position_13': 202,
#  'Position_14': 203,
#  'Position_15': 204,
#  'Position_16': 205,
#  'Position_17': 206,
#  'Position_18': 207,
#  'Position_19': 208,
#  'Position_20': 209,
#  'Position_21': 210,
#  'Position_22': 211,
#  'Position_23': 212,
#  'Position_24': 213,
#  'Position_25': 214,
#  'Position_26': 215,
#  'Position_27': 216,
#  'Position_28': 217,
#  'Position_29': 218,
#  'Position_30': 219,
#  'Position_31': 220,
#  'PitchDrum_27': 221,
#  'PitchDrum_28': 222,
#  'PitchDrum_29': 223,
#  'PitchDrum_30': 224,
#  'PitchDrum_31': 225,
#  'PitchDrum_32': 226,
#  'PitchDrum_33': 227,
#  'PitchDrum_34': 228,
#  'PitchDrum_35': 229,
#  'PitchDrum_36': 230,
#  'PitchDrum_37': 231,
#  'PitchDrum_38': 232,
#  'PitchDrum_39': 233,
#  'PitchDrum_40': 234,
#  'PitchDrum_41': 235,
#  'PitchDrum_42': 236,
#  'PitchDrum_43': 237,
#  'PitchDrum_44': 238,
#  'PitchDrum_45': 239,
#  'PitchDrum_46': 240,
#  'PitchDrum_47': 241,
#  'PitchDrum_48': 242,
#  'PitchDrum_49': 243,
#  'PitchDrum_50': 244,
#  'PitchDrum_51': 245,
#  'PitchDrum_52': 246,
#  'PitchDrum_53': 247,
#  'PitchDrum_54': 248,
#  'PitchDrum_55': 249,
#  'PitchDrum_56': 250,
#  'PitchDrum_57': 251,
#  'PitchDrum_58': 252,
#  'PitchDrum_59': 253,
#  'PitchDrum_60': 254,
#  'PitchDrum_61': 255,
#  'PitchDrum_62': 256,
#  'PitchDrum_63': 257,
#  'PitchDrum_64': 258,
#  'PitchDrum_65': 259,
#  'PitchDrum_66': 260,
#  'PitchDrum_67': 261,
#  'PitchDrum_68': 262,
#  'PitchDrum_69': 263,
#  'PitchDrum_70': 264,
#  'PitchDrum_71': 265,
#  'PitchDrum_72': 266,
#  'PitchDrum_73': 267,
#  'PitchDrum_74': 268,
#  'PitchDrum_75': 269,
#  'PitchDrum_76': 270,
#  'PitchDrum_77': 271,
#  'PitchDrum_78': 272,
#  'PitchDrum_79': 273,
#  'PitchDrum_80': 274,
#  'PitchDrum_81': 275,
#  'PitchDrum_82': 276,
#  'PitchDrum_83': 277,
#  'PitchDrum_84': 278,
#  'PitchDrum_85': 279,
#  'PitchDrum_86': 280,
#  'PitchDrum_87': 281}

# %%
tokens[0].tokens
# Out:
# ['Bar_None',
#  'Position_16',
#  'Pitch_67',
#  'Velocity_51',
#  'Duration_1.6.8',
#  'Position_27',
#  'Pitch_72',
#  'Velocity_59',
#  'Duration_0.7.8',
#  'Bar_None',
#  'Position_1',
#  'Pitch_78',
#  'Velocity_71',
#  'Duration_3.2.8',
#  'Pitch_61',
#  'Velocity_43',
#  'Duration_3.4.8',
#  'Pitch_67',
#  'Velocity_55',
#  'Duration_3.4.8',
#  'Position_2',
#  'Pitch_71',
#  'Velocity_55',
#  'Duration_3.0.8',
#  'Position_24',
#  'Pitch_79',
#  'Velocity_59',
#  'Duration_0.6.8',
#  'Bar_None',
#  'Position_0',
#  'Pitch_79',
#  'Velocity_75',
#  'Duration_1.1.8',
#  'Pitch_67',
#  'Velocity_59',
#  'Duration_1.1.8',
#  'Pitch_70',
#  'Velocity_59',
#  'Duration_1.5.8',
#  'Pitch_60',
#  'Velocity_43',
#  'Duration_1.4.8',
#  'Position_6',
#  'Pitch_75',
#  'Velocity_75',
#  'Duration_0.4.8',
#  'Position_12',
#  'Pitch_59',
#  'Velocity_55',
#  'Duration_0.6.8',
#  'Pitch_75',
#  'Velocity_83',
#  'Duration_1.0.8',
#  'Pitch_69',
#  'Velocity_59',
#  'Duration_1.0.8',
#  'Pitch_67',
#  'Velocity_59',
#  'Duration_1.0.8',
#  'Position_18',
#  'Pitch_71',
#  'Velocity_71',
#  'Duration_1.0.8',
#  'Position_26',
#  'Pitch_74',
#  'Velocity_71',
#  'Duration_3.0.8',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_6.0.4',
#  'Pitch_64',
#  'Velocity_51',
#  'Duration_2.2.8',
#  'Pitch_68',
#  'Velocity_59',
#  'Duration_0.1.8',
#  'Position_27',
#  'Pitch_68',
#  'Velocity_19',
#  'Duration_1.3.8',
#  'Bar_None',
#  'Position_5',
#  'Pitch_67',
#  'Velocity_43',
#  'Duration_0.2.8',
#  'Position_9',
#  'Pitch_67',
#  'Velocity_47',
#  'Duration_1.2.8',
#  'Position_17',
#  'Pitch_73',
#  'Velocity_51',
#  'Duration_0.3.8',
#  'Position_26',
#  'Pitch_73',
#  'Velocity_47',
#  'Duration_3.3.8',
#  'Pitch_67',
#  'Velocity_51',
#  'Duration_1.5.8',
#  'Position_27',
#  'Pitch_42',
#  'Velocity_35',
#  'Duration_2.0.8',
#  'Bar_None',
#  'Position_8',
#  'Pitch_66',
#  'Velocity_35',
#  'Duration_0.2.8',
#  'Position_16',
#  'Pitch_62',
#  'Velocity_39',
#  'Duration_4.0.4',
#  'Pitch_66',
#  'Velocity_43',
#  'Duration_3.7.8',
#  'Pitch_35',
#  'Velocity_39',
#  'Duration_1.7.8',
#  'Position_29',
#  'Pitch_42',
#  'Velocity_31',
#  'Duration_0.6.8',
#  'Bar_None',
#  'Position_2',
#  'Pitch_47',
#  'Velocity_27',
#  'Duration_1.6.8',
#  'Position_13',
#  'Pitch_74',
#  'Velocity_55',
#  'Duration_1.3.8',
#  'Position_21',
#  'Pitch_70',
#  'Velocity_71',
#  'Duration_1.2.8',
#  'Pitch_62',
#  'Velocity_59',
#  'Duration_1.0.8',
#  'Position_28',
#  'Pitch_66',
#  'Velocity_75',
#  'Duration_0.2.8',
#  'Position_31',
#  'Pitch_60',
#  'Velocity_67',
#  'Duration_0.7.8',
#  'Bar_None',
#  'Position_4',
#  'Pitch_77',
#  'Velocity_79',
#  'Duration_1.5.8',
#  'Pitch_69',
#  'Velocity_63',
#  'Duration_2.0.8',
#  'Pitch_61',
#  'Velocity_59',
#  'Duration_3.5.8',
#  'Pitch_65',
#  'Velocity_67',
#  'Duration_2.0.8',
#  'Position_15',
#  'Pitch_76',
#  'Velocity_63',
#  'Duration_0.2.8',
#  'Position_19',
#  'Pitch_76',
#  'Velocity_75',
#  'Duration_1.5.8',
#  'Position_26',
#  'Pitch_66',
#  'Velocity_63',
#  'Duration_0.4.8',
#  'Pitch_70',
#  'Velocity_67',
#  'Duration_0.6.8',
#  'Position_28',
#  'Pitch_62',
#  'Velocity_59',
#  'Duration_0.1.8',
#  'Bar_None',
#  'Position_0',
#  'Pitch_71',
#  'Velocity_75',
#  'Duration_1.0.8',
#  'Pitch_67',
#  'Velocity_71',
#  'Duration_1.1.8',
#  'Pitch_62',
#  'Velocity_63',
#  'Duration_1.3.8',
#  'Position_5',
#  'Pitch_77',
#  'Velocity_79',
#  'Duration_0.4.8',
#  'Position_8',
#  'Pitch_76',
#  'Velocity_79',
#  'Duration_0.4.8',
#  'Position_11',
#  'Pitch_63',
#  'Velocity_75',
#  'Duration_1.4.8',
#  'Pitch_75',
#  'Velocity_87',
#  'Duration_1.0.8',
#  'Pitch_70',
#  'Velocity_79',
#  'Duration_0.3.8',
#  'Pitch_66',
#  'Velocity_75',
#  'Duration_0.6.8',
#  'Position_17',
#  'Pitch_70',
#  'Velocity_91',
#  'Duration_0.2.8',
#  'Position_22',
#  'Pitch_81',
#  'Velocity_95',
#  'Duration_1.4.8',
#  'Pitch_75',
#  'Velocity_79',
#  'Duration_1.5.8',
#  'Pitch_74',
#  'Velocity_79',
#  'Duration_0.7.8',
#  'Pitch_59',
#  'Velocity_71',
#  'Duration_0.7.8',
#  'Position_28',
#  'Pitch_54',
#  'Velocity_75',
#  'Duration_1.1.8',
#  'Position_31',
#  'Pitch_73',
#  'Velocity_71',
#  'Duration_0.1.8',
#  'Bar_None',
#  'Position_2',
#  'Pitch_65',
#  'Velocity_83',
#  'Duration_0.4.8',
#  'Pitch_73',
#  'Velocity_79',
#  'Duration_1.0.8',
#  'Position_9',
#  'Pitch_82',
#  'Velocity_99',
#  'Duration_1.0.8',
#  'Position_16',
#  'Pitch_78',
#  'Velocity_95',
#  'Duration_0.6.8',
#  'Pitch_66',
#  'Velocity_79',
#  'Duration_0.6.8',
#  'Pitch_70',
#  'Velocity_79',
#  'Duration_0.6.8',
#  'Position_21',
#  'Pitch_74',
#  'Velocity_91',
#  'Duration_0.6.8',
#  'Position_24',
#  'Pitch_71',
#  'Velocity_79',
#  'Duration_0.1.8',
#  'Pitch_67',
#  'Velocity_75',
#  'Duration_0.1.8',
#  'Position_26',
#  'Pitch_85',
#  'Velocity_107',
#  'Duration_0.6.8',
#  'Pitch_71',
#  'Velocity_87',
#  'Duration_0.4.8',
#  'Pitch_67',
#  'Velocity_83',
#  'Duration_0.4.8',
#  'Position_27',
#  'Pitch_86',
#  'Velocity_55',
#  'Duration_0.1.8',
#  'Position_28',
#  'Pitch_86',
#  'Velocity_7',
#  'Duration_0.2.8',
#  'Position_31',
#  'Pitch_81',
#  'Velocity_95',
#  'Duration_0.5.8',
#  'Bar_None',
#  'Position_1',
#  'Pitch_68',
#  'Velocity_79',
#  'Duration_0.1.8',
#  'Pitch_72',
#  'Velocity_79',
#  'Duration_0.1.8',
#  'Position_4',
#  'Pitch_68',
#  'Velocity_87',
#  'Duration_0.3.8',
#  'Pitch_72',
#  'Velocity_87',
#  'Duration_0.4.8',
#  'Pitch_77',
#  'Velocity_99',
#  'Duration_0.4.8',
#  'Position_9',
#  'Pitch_81',
#  'Velocity_107',
#  'Duration_0.5.8',
#  'Position_10',
#  'Pitch_76',
#  'Velocity_23',
#  'Duration_0.1.8',
#  'Position_11',
#  'Pitch_73',
#  'Velocity_83',
#  'Duration_0.2.8',
#  'Pitch_69',
#  'Velocity_75',
#  'Duration_0.1.8',
#  'Position_14',
#  'Pitch_75',
#  'Velocity_103',
#  'Duration_1.0.8',
#  'Pitch_69',
#  'Velocity_87',
#  'Duration_0.2.8',
#  'Pitch_73',
#  'Velocity_91',
#  'Duration_0.2.8',
#  'Position_20',
#  'Pitch_67',
#  'Velocity_83',
#  'Duration_0.2.8',
#  'Pitch_71',
#  'Velocity_91',
#  'Duration_0.1.8',
#  'Pitch_59',
#  'Velocity_87',
#  'Duration_0.2.8',
#  'Position_22',
#  'Pitch_81',
#  'Velocity_99',
#  'Duration_0.4.8',
#  'Position_25',
#  'Pitch_69',
#  'Velocity_99',
#  'Duration_0.2.8',
#  'Pitch_71',
#  'Velocity_95',
#  'Duration_1.0.8',
#  'Pitch_65',
#  'Velocity_91',
#  'Duration_0.2.8',
#  'Pitch_57',
#  'Velocity_95',
#  'Duration_0.2.8',
#  'Pitch_72',
#  'Velocity_91',
#  'Duration_0.1.8',
#  'Position_31',
#  'Pitch_67',
#  'Velocity_99',
#  'Duration_0.1.8',
#  'Pitch_55',
#  'Velocity_91',
#  'Duration_0.2.8',
#  'Pitch_63',
#  'Velocity_99',
#  'Duration_0.2.8',
#  'Bar_None',
#  'Position_1',
#  'Pitch_81',
#  'Velocity_107',
#  'Duration_0.4.8',
#  'Position_4',
#  'Pitch_67',
#  'Velocity_107',
#  'Duration_3.2.8',
#  'Pitch_65',
#  'Velocity_99',
#  'Duration_0.2.8',
#  'Pitch_53',
#  'Velocity_95',
#  'Duration_0.2.8',
#  'Pitch_61',
#  'Velocity_103',
#  'Duration_0.2.8',
#  'Position_5',
#  'Pitch_79',
#  'Velocity_43',
#  'Duration_0.1.8',
#  'Position_11',
#  'Pitch_63',
#  'Velocity_107',
#  'Duration_0.1.8',
#  'Pitch_59',
#  'Velocity_91',
#  'Duration_0.2.8',
#  'Pitch_51',
#  'Velocity_95',
#  'Duration_0.3.8',
#  'Position_19',
#  'Pitch_62',
#  'Velocity_103',
#  'Duration_0.1.8',
#  'Pitch_50',
#  'Velocity_95',
#  'Duration_0.2.8',
#  'Pitch_58',
#  'Velocity_99',
#  'Duration_0.1.8',
#  'Pitch_54',
#  'Velocity_91',
#  'Duration_0.2.8',
#  'Position_27',
#  'Pitch_40',
#  'Velocity_103',
#  'Duration_5.0.4',
#  'Pitch_28',
#  'Velocity_95',
#  'Duration_5.0.4',
#  'Position_31',
#  'Pitch_68',
#  'Velocity_103',
#  'Duration_0.3.8',
#  'Bar_None',
#  'Position_5',
#  'Pitch_68',
#  'Velocity_103',
#  'Duration_1.1.8',
#  'Pitch_57',
#  'Velocity_87',
#  'Duration_1.2.8',
#  'Pitch_61',
#  'Velocity_87',
#  'Duration_1.1.8',
#  'Position_13',
#  'Pitch_64',
#  'Velocity_91',
#  'Duration_0.2.8',
#  'Position_19',
#  'Pitch_64',
#  'Velocity_95',
#  'Duration_1.0.8',
#  'Pitch_60',
#  'Velocity_83',
#  'Duration_0.5.8',
#  'Position_20',
#  'Pitch_52',
#  'Velocity_79',
#  'Duration_1.1.8',
#  'Pitch_56',
#  'Velocity_67',
#  'Duration_1.3.8',
#  'Position_26',
#  'Pitch_60',
#  'Velocity_91',
#  'Duration_0.7.8',
#  'Bar_None',
#  'Position_2',
#  'Pitch_63',
#  'Velocity_91',
#  'Duration_1.5.8',
#  'Pitch_59',
#  'Velocity_71',
#  'Duration_1.4.8',
#  'Pitch_55',
#  'Velocity_71',
#  'Duration_1.4.8',
#  'Position_10',
#  'Pitch_33',
#  'Velocity_71',
#  'Duration_4.2.4',
#  'Position_14',
#  'Pitch_62',
#  'Velocity_71',
#  'Duration_0.3.8',
#  'Position_19',
#  'Pitch_62',
#  'Velocity_75',
#  'Duration_1.0.8',
#  'Pitch_54',
#  'Velocity_59',
#  'Duration_1.5.8',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_1.3.8',
#  'Position_27',
#  'Pitch_61',
#  'Velocity_67',
#  'Duration_3.0.8',
#  'Bar_None',
#  'Position_3',
#  'Pitch_57',
#  'Velocity_51',
#  'Duration_3.0.8',
#  'Pitch_53',
#  'Velocity_51',
#  'Duration_0.5.8',
#  'Position_12',
#  'Pitch_54',
#  'Velocity_55',
#  'Duration_0.7.8',
#  'Position_18',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_8.3.4',
#  'Position_26',
#  'Pitch_51',
#  'Velocity_55',
#  'Duration_1.2.8',
#  'Pitch_55',
#  'Velocity_47',
#  'Duration_4.3.4',
#  'Bar_None',
#  'Position_3',
#  'Pitch_45',
#  'Velocity_43',
#  'Duration_5.0.4',
#  'Position_8',
#  'Pitch_50',
#  'Velocity_43',
#  'Duration_0.3.8',
#  'Position_13',
#  'Pitch_50',
#  'Velocity_39',
#  'Duration_1.5.8',
#  'Position_25',
#  'Pitch_49',
#  'Velocity_35',
#  'Duration_1.6.8',
#  'Position_31',
#  'Pitch_53',
#  'Velocity_39',
#  'Duration_1.7.8',
#  'Bar_None',
#  'Position_8',
#  'Pitch_48',
#  'Velocity_39',
#  'Duration_0.6.8',
#  'Position_12',
#  'Pitch_54',
#  'Velocity_47',
#  'Duration_0.3.8',
#  'Position_18',
#  'Pitch_54',
#  'Velocity_55',
#  'Duration_1.1.8',
#  'Pitch_48',
#  'Velocity_39',
#  'Duration_1.5.8',
#  'Pitch_38',
#  'Velocity_43',
#  'Duration_1.7.8',
#  'Pitch_45',
#  'Velocity_31',
#  'Duration_2.0.8',
#  'Position_25',
#  'Pitch_57',
#  'Velocity_51',
#  'Duration_0.6.8',
#  'Position_30',
#  'Pitch_64',
#  'Velocity_51',
#  'Duration_0.3.8',
#  'Bar_None',
#  'Position_2',
#  'Pitch_60',
#  'Velocity_63',
#  'Duration_0.4.8',
#  'Position_5',
#  'Pitch_68',
#  'Velocity_63',
#  'Duration_0.5.8',
#  'Position_9',
#  'Pitch_74',
#  'Velocity_67',
#  'Duration_1.1.8',
#  'Position_10',
#  'Pitch_71',
#  'Velocity_55',
#  'Duration_1.1.8',
#  'Pitch_66',
#  'Velocity_39',
#  'Duration_0.1.8',
#  'Pitch_62',
#  'Velocity_43',
#  'Duration_0.5.8',
#  'Position_11',
#  'Pitch_66',
#  'Velocity_7',
#  'Duration_0.3.8',
#  'Position_13',
#  'Pitch_32',
#  'Velocity_51',
#  'Duration_0.4.8',
#  'Position_16',
#  'Pitch_35',
#  'Velocity_55',
#  'Duration_0.2.8',
#  'Position_19',
#  'Pitch_70',
#  'Velocity_63',
#  'Duration_0.4.8',
#  'Pitch_64',
#  'Velocity_51',
#  'Duration_0.4.8',
#  'Pitch_42',
#  'Velocity_59',
#  'Duration_0.1.8',
#  'Pitch_60',
#  'Velocity_43',
#  'Duration_0.5.8',
#  'Position_22',
#  'Pitch_38',
#  'Velocity_59',
#  'Duration_0.5.8',
#  'Position_26',
#  'Pitch_46',
#  'Velocity_71',
#  'Duration_0.5.8',
#  'Position_30',
#  'Pitch_63',
#  'Velocity_63',
#  'Duration_0.6.8',
#  'Pitch_52',
#  'Velocity_63',
#  'Duration_1.4.8',
#  'Pitch_59',
#  'Velocity_51',
#  'Duration_0.5.8',
#  'Pitch_55',
#  'Velocity_47',
#  'Duration_1.4.8',
#  'Bar_None',
#  'Position_9',
#  'Pitch_67',
#  'Velocity_51',
#  'Duration_0.6.8',
#  'Pitch_62',
#  'Velocity_47',
#  'Duration_0.6.8',
#  'Pitch_48',
#  'Velocity_47',
#  'Duration_1.3.8',
#  'Pitch_58',
#  'Velocity_43',
#  'Duration_0.6.8',
#  'Position_20',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.6.8',
#  'Pitch_41',
#  'Velocity_39',
#  'Duration_0.7.8',
#  'Pitch_54',
#  'Velocity_43',
#  'Duration_0.5.8',
#  'Position_29',
#  'Pitch_59',
#  'Velocity_47',
#  'Duration_0.2.8',
#  'Pitch_55',
#  'Velocity_47',
#  'Duration_0.2.8',
#  'Bar_None',
#  'Position_3',
#  'Pitch_59',
#  'Velocity_35',
#  'Duration_0.6.8',
#  'Pitch_45',
#  'Velocity_39',
#  'Duration_1.6.8',
#  'Pitch_39',
#  'Velocity_35',
#  'Duration_0.6.8',
#  'Pitch_49',
#  'Velocity_35',
#  'Duration_1.0.8',
#  'Pitch_55',
#  'Velocity_43',
#  'Duration_0.6.8',
#  'Position_16',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_1.3.8',
#  'Pitch_40',
#  'Velocity_51',
#  'Duration_2.2.8',
#  'Pitch_56',
#  'Velocity_51',
#  'Duration_1.1.8',
#  'Pitch_50',
#  'Velocity_39',
#  'Duration_0.7.8',
#  'Position_25',
#  'Pitch_61',
#  'Velocity_67',
#  'Duration_0.2.8',
#  'Position_30',
#  'Pitch_55',
#  'Velocity_63',
#  'Duration_1.0.8',
#  'Pitch_61',
#  'Velocity_67',
#  'Duration_1.5.8',
#  'Position_31',
#  'Pitch_45',
#  'Velocity_55',
#  'Duration_1.6.8',
#  'Pitch_52',
#  'Velocity_51',
#  'Duration_1.6.8',
#  'Bar_None',
#  'Position_6',
#  'Pitch_64',
#  'Velocity_67',
#  'Duration_0.6.8',
#  'Position_11',
#  'Pitch_71',
#  'Velocity_75',
#  'Duration_0.3.8',
#  'Position_15',
#  'Pitch_67',
#  'Velocity_79',
#  'Duration_0.4.8',
#  'Position_19',
#  'Pitch_75',
#  'Velocity_79',
#  'Duration_0.4.8',
#  'Position_23',
#  'Pitch_83',
#  'Velocity_83',
#  'Duration_0.6.8',
#  'Pitch_77',
#  'Velocity_75',
#  'Duration_1.4.8',
#  'Pitch_53',
#  'Velocity_63',
#  'Duration_0.5.8',
#  'Pitch_71',
#  'Velocity_67',
#  'Duration_1.0.8',
#  'Pitch_44',
#  'Velocity_63',
#  'Duration_1.3.8',
#  'Pitch_50',
#  'Velocity_59',
#  'Duration_0.5.8',
#  'Bar_None',
#  'Position_2',
#  'Pitch_53',
#  'Velocity_67',
#  'Duration_0.5.8',
#  'Pitch_74',
#  'Velocity_67',
#  'Duration_0.7.8',
#  'Pitch_56',
#  'Velocity_59',
#  'Duration_0.6.8',
#  'Pitch_46',
#  'Velocity_67',
#  'Duration_0.5.8',
#  'Position_5',
#  'Pitch_70',
#  'Velocity_75',
#  'Duration_0.4.8',
#  'Position_8',
#  'Pitch_78',
#  'Velocity_83',
#  'Duration_0.4.8',
#  'Position_12',
#  'Pitch_81',
#  'Velocity_87',
#  'Duration_0.4.8',
#  'Pitch_69',
#  'Velocity_67',
#  'Duration_1.3.8',
#  'Pitch_53',
#  'Velocity_59',
#  'Duration_0.4.8',
#  'Pitch_73',
#  'Velocity_67',
#  'Duration_0.4.8',
#  'Pitch_47',
#  'Velocity_55',
#  'Duration_0.6.8',
#  'Position_15',
#  'Pitch_49',
#  'Velocity_67',
#  'Duration_0.3.8',
#  'Position_18',
#  'Pitch_57',
#  'Velocity_67',
#  'Duration_0.1.8',
#  'Position_22',
#  'Pitch_80',
#  'Velocity_79',
#  'Duration_0.7.8',
#  'Pitch_70',
#  'Velocity_67',
#  'Duration_0.5.8',
#  'Pitch_48',
#  'Velocity_67',
#  'Duration_0.6.8',
#  'Pitch_63',
#  'Velocity_63',
#  'Duration_0.4.8',
#  'Position_26',
#  'Pitch_66',
#  'Velocity_63',
#  'Duration_0.5.8',
#  'Position_31',
#  'Pitch_73',
#  'Velocity_59',
#  'Duration_0.7.8',
#  'Bar_None',
#  'Position_4',
#  'Pitch_79',
#  'Velocity_59',
#  'Duration_0.7.8',
#  'Pitch_75',
#  'Velocity_43',
#  'Duration_1.0.8',
#  'Pitch_59',
#  'Velocity_39',
#  'Duration_0.7.8',
#  'Pitch_55',
#  'Velocity_31',
#  'Duration_1.0.8',
#  'Position_5',
#  'Pitch_49',
#  'Velocity_19',
#  'Duration_1.1.8',
#  'Position_21',
#  'Pitch_56',
#  'Velocity_67',
#  'Duration_1.3.8',
#  'Pitch_50',
#  'Velocity_47',
#  'Duration_1.7.8',
#  'Position_25',
#  'Pitch_52',
#  'Velocity_71',
#  'Duration_0.5.8',
#  'Position_30',
#  'Pitch_60',
#  'Velocity_83',
#  'Duration_0.7.8',
#  'Bar_None',
#  'Position_4',
#  'Pitch_66',
#  'Velocity_83',
#  'Duration_3.3.8',
#  'Pitch_49',
#  'Velocity_55',
#  'Duration_1.7.8',
#  'Pitch_59',
#  'Velocity_63',
#  'Duration_1.0.8',
#  'Pitch_55',
#  'Velocity_59',
#  'Duration_1.0.8',
#  'Position_18',
#  'Pitch_56',
#  'Velocity_47',
#  'Duration_1.0.8',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_1.4.8',
#  'Position_19',
#  'Pitch_50',
#  'Velocity_47',
#  'Duration_1.7.8',
#  'Position_27',
#  'Pitch_67',
#  'Velocity_75',
#  'Duration_0.4.8',
#  'Bar_None',
#  'Position_2',
#  'Pitch_67',
#  'Velocity_87',
#  'Duration_0.7.8',
#  'Pitch_49',
#  'Velocity_63',
#  'Duration_1.2.8',
#  'Pitch_55',
#  'Velocity_67',
#  'Duration_1.0.8',
#  'Pitch_59',
#  'Velocity_63',
#  'Duration_1.0.8',
#  'Position_8',
#  'Pitch_63',
#  'Velocity_87',
#  'Duration_0.3.8',
#  'Position_14',
#  'Pitch_63',
#  'Velocity_91',
#  'Duration_0.7.8',
#  'Pitch_48',
#  'Velocity_67',
#  'Duration_0.6.8',
#  'Pitch_57',
#  'Velocity_71',
#  'Duration_1.1.8',
#  'Pitch_54',
#  'Velocity_67',
#  'Duration_0.6.8',
#  'Position_20',
#  'Pitch_59',
#  'Velocity_87',
#  'Duration_1.0.8',
#  'Position_28',
#  'Pitch_62',
#  'Velocity_87',
#  'Duration_1.1.8',
#  'Pitch_47',
#  'Velocity_67',
#  'Duration_1.7.8',
#  'Pitch_53',
#  'Velocity_71',
#  'Duration_1.4.8',
#  'Pitch_56',
#  'Velocity_71',
#  'Duration_1.1.8',
#  'Bar_None',
#  'Position_5',
#  'Pitch_61',
#  'Velocity_83',
#  'Duration_0.3.8',
#  'Position_9',
#  'Pitch_52',
#  'Velocity_79',
#  'Duration_0.5.8',
#  'Pitch_61',
#  'Velocity_83',
#  'Duration_0.7.8',
#  'Position_13',
#  'Pitch_56',
#  'Velocity_79',
#  'Duration_0.2.8',
#  'Position_14',
#  'Pitch_62',
#  'Velocity_87',
#  'Duration_0.7.8',
#  'Position_16',
#  'Pitch_67',
#  'Velocity_87',
#  'Duration_0.1.8',
#  'Position_21',
#  'Pitch_63',
#  'Velocity_83',
#  'Duration_0.7.8',
#  'Pitch_73',
#  'Velocity_95',
#  'Duration_3.6.8',
#  'Pitch_58',
#  'Velocity_79',
#  'Duration_0.6.8',
#  'Pitch_66',
#  'Velocity_91',
#  'Duration_2.3.8',
#  'Position_28',
#  'Pitch_64',
#  'Velocity_95',
#  'Duration_0.1.8',
#  'Pitch_54',
#  'Velocity_91',
#  'Duration_0.1.8',
#  'Bar_None',
#  'Position_1',
#  'Pitch_43',
#  'Velocity_83',
#  'Duration_0.3.8',
#  'Position_8',
#  'Pitch_65',
#  'Velocity_91',
#  'Duration_1.0.8',
#  'Pitch_55',
#  'Velocity_79',
#  'Duration_3.3.8',
#  'Pitch_58',
#  'Velocity_75',
#  'Duration_3.4.8',
#  'Position_18',
#  'Pitch_74',
#  'Velocity_79',
#  'Duration_0.5.8',
#  'Position_21',
#  'Pitch_64',
#  'Velocity_79',
#  'Duration_0.2.8',
#  'Position_25',
#  ...]

# %%
# Initialize tokenizer
tokenizer = miditok.REMI()


def tokenize_midi_files(midi_files, tokenizer):
    tokenized_data = []
    for midi in midi_files:

        tokens = tokenizer(midi)
        tokenized_seq = " ".join(map(str, tokens[0].ids))  # Convert to text-like format
        tokenized_data.append({"text": tokenized_seq})
    return Dataset.from_list(tokenized_data)

# List of MIDI files (update with your dataset)
midi_files = [get_midi_path(1)]


# Convert MIDI to text sequences
dataset = tokenize_midi_files(midi_files, tokenizer)

# Check the processed data
print(dataset[0])
# Out:
# {'text': '4 205 51 105 138 216 56 107 131 4 190 62 110 150 45 103 152 51 106 152 191 55 106 148 213 63 107 130 4 189 63 111 133 51 107 133 54 107 137 44 103 136 195 59 111 128 201 43 106 130 59 113 132 53 107 132 51 107 132 207 55 110 132 215 58 110 148 42 106 164 48 105 142 52 107 125 216 52 97 135 4 194 51 103 126 198 51 104 134 206 57 105 127 215 57 104 151 51 105 137 216 26 101 140 4 197 50 101 126 205 46 102 156 50 103 155 19 102 139 218 26 100 130 4 191 31 99 138 202 58 106 135 210 54 110 134 46 107 132 217 50 111 126 220 44 109 131 4 193 61 112 137 53 108 140 45 107 153 49 109 140 204 60 108 126 208 60 111 137 215 50
 110 133 4 194 45 113 127 198 36 112 129 45 113 131 202 40 112 126 203 46 114 131 205 51 114 125 210 47 113 131 57 116 154 42 112 130 50 115 143 217 48 116 125 38 115 125 4 190 27 113 127 197 49 115 132 39 112 151 42 111 152 207 58 112 129 210 48 112 126 214 58 113 131 48 108 134 220 54 112 128 4 194 54 114 133 200 50 113 127 49 105 125 203 48 108 128 207 53 112 134 49 109 129 47 105 131 214 42 107 128 216 61 111 125 219 61 114 129 35 107 132 53 110 126 4 193 30 109 130 57 113 127 54 111 126 198 41 110 133 199 57 114 130 50 114 130 204 53 114 126 45 113 125 210 58 115 128 40 1 ...

# %% [markdown]
# the tokenizer seems to work . now we have to load the model and extend the tokenizer in the model with our tokens

# %% [markdown]
#  Recap: Where We Are
# ✅ Downloaded MIDI dataset (a folder of .mid files).
# ✅ Used miditok to tokenize MIDI files into sequences.
# ✅ Decided between two training approaches:
# Approach A: Convert MIDI tokens into a text format (e.g., velocity pitch bar <EOS>) and train GPT-2 using the extended GPT-2 tokenizer.
# Approach B: Train GPT-2 directly on integer token sequences without using GPT-2’s built-in tokenizer, using miditok as the tokenizer instead.

# %% [markdown]
# I decide to go with the first approach :
#
# 1. convert all dataset to text:
# for midifile in midifiles :
# return miditok_text (midifile)
# 2. extend GPT2 tokenizer,
# 3. train on converted midi files to text

# %%
# Get special tokens from MIDI tokenizer
midi_vocab = tokenizer.vocab  # Extract MIDI vocabulary from miditok
print("MIDI Vocabulary Size:", len(midi_vocab))
# Out:
# MIDI Vocabulary Size: 282

# %%
from transformers import AutoTokenizer

# Load pre-trained GPT-2 tokenizer
gpt_tokenizer = AutoTokenizer.from_pretrained("gpt2")

# Print original vocab size
print("Original GPT-2 Vocabulary Size:", len(gpt_tokenizer))

# Add a padding token
gpt_tokenizer.add_special_tokens({'pad_token': '[PAD]'})

# Add MIDI tokens to the tokenizer's vocabulary
gpt_tokenizer.add_tokens(list(midi_vocab.keys()))

print("Final Vocabulary Size:", len(gpt_tokenizer))
# Out:
# Original GPT-2 Vocabulary Size: 50257
# Final Vocabulary Size: 50540

# %%
from transformers import GPT2LMHeadModel

# Load pre-trained GPT-2 model
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Resize token embeddings to match the new vocabulary size
model.resize_token_embeddings(len(gpt_tokenizer))

print("GPT-2 Model Updated with New MIDI Tokens!")
# Out:
# GPT-2 Model Updated with New MIDI Tokens!

# %% [markdown]
# ## process the data

# %%
import os
import miditok
import miditoolkit
from tqdm import tqdm



# Initialize MIDI tokenizer
midi_tokenizer = miditok.REMI()  # Use your preferred tokenization method

def midi_to_text(midi_path, composer="Unknown", piece_type="Unknown"):
    """
    Converts a MIDI file to structured text format for GPT-2 training.

    Args:
        midi_path (str): Path to the MIDI file.
        composer (str): Composer name.
        piece_type (str): Type of the piece (e.g., Sonata, Waltz).

    Returns:
        str: Tokenized text format of the MIDI file.
    """
    try:


        # Tokenize MIDI using miditok
        tokens = tokenizer(midi_path)
        tokenized_seq = tokens[0].tokens  # Get token IDs

        # Convert token IDs to a text-friendly format
        token_text = " ".join(map(str, tokenized_seq))

        # Add metadata headers
        text_output = f"<COMPOSER> {composer} <PIECE_TYPE> {piece_type} <BOS> {token_text} <EOS>"
        return text_output

    except Exception as e:
        print(f"Error processing {midi_path}: {e}")
        return None  # Skip problematic files

# %%
midi_to_text(get_midi_path(0))
# Out:
# '<COMPOSER> Unknown <PIECE_TYPE> Unknown <BOS> Bar_None Position_16 Pitch_67 Velocity_51 Duration_1.5.8 Position_29 Pitch_72 Velocity_67 Duration_0.2.8 Bar_None Position_2 Pitch_78 Velocity_67 Duration_2.7.8 Pitch_71 Velocity_47 Duration_4.2.4 Position_3 Pitch_61 Velocity_39 Duration_2.1.8 Pitch_67 Velocity_39 Duration_2.0.8 Bar_None Position_2 Pitch_79 Velocity_59 Duration_0.5.8 Position_12 Pitch_79 Velocity_71 Duration_0.6.8 Pitch_60 Velocity_47 Duration_1.2.8 Pitch_70 Velocity_63 Duration_1.0.8 Pitch_67 Velocity_55 Duration_1.1.8 Position_19 Pitch_75 Velocity_71 Duration_0.1.8 Position_25 Pitch_75 Velocity_83 Duration_0.6.8 Pitch_69 Velocity_63 Duration_0.5.8 Pitch_59 Velocity_55 Duration_1.5.8 Pitch_67 Velocity_63 Duration_0.7.8 Position_29 Pitch_71 Velocity_71 Duration_0.1.8 Bar_None Position_5 Pitch_74 Velocity_71 Duration_3.7.8 Pitch_64 Velocity_47 Duration_2.5.8 Pitch_68 Velocity_63 Duration_1.2.8 Pitch_58 Velocity_55 Duration_2.1.8 Position_15 Pitch_67 Velocity_47 Duration_0.1.8 Position_18 Pitch_67 Velocity_63 Duration_1.1.8 Position_24 Pitch_73 Velocity_59 Duration_0.3.8 Bar_None Position_2 Pitch_67 Velocity_43 Duration_0.7.8 Position_3 Pitch_73 Velocity_47 Duration_3.6.8 Pitch_42 Velocity_43 Duration_1.6.8 Position_20 Pitch_66 Velocity_43 Duration_0.2.8 Position_30 Pitch_35 Velocity_31 Duration_1.6.8 Pitch_62 Velocity_35 Duration_7.2.4 Pitch_66 Velocity_35 Duration_8.1.4 Bar_None Position_23 Pitch_42 Velocity_35 Duration_1.1.8 Bar_None Position_9 Pitch_47 Velocity_27 Duration_1.4.8 Bar_None Position_9 Pitch_74 Velocity_43 Duration_1.5.8 Position_18 Pitch_62 Velocity_39 Duration_1.0.8 Pitch_70 Velocity_63 Duration_2.2.8 Position_25 Pitch_66 Velocity_71 Duration_0.3.8 Position_28 Pitch_60 Velocity_55 Duration_0.1.8 Bar_None Position_3 Pitch_77 Velocity_71 Duration_0.7.8 Position_4 Pitch_61 Velocity_43 Duration_2.6.8 Pitch_65 Velocity_39 Duration_2.2.8 Pitch_69 Velocity_55 Duration_1.7.8 Position_16 Pitch_76 Velocity_51 Duration_0.1.8 Position_20 Pitch_76 Velocity_59 Duration_1.4.8 Position_26 Pitch_70 Velocity_55 Duration_0.2.8 Pitch_66 Velocity_47 Duration_0.3.8 Position_28 Pitch_62 Velocity_55 Duration_0.1.8 Position_31 Pitch_67 Velocity_55 Duration_0.7.8 Pitch_71 Velocity_59 Duration_0.7.8 Pitch_62 Velocity_55 Duration_0.7.8 Bar_None Position_5 Pitch_77 Velocity_63 Duration_0.5.8 Position_7 Pitch_76 Velocity_63 Duration_0.3.8 Position_11 Pitch_75 Velocity_75 Duration_1.1.8 Pitch_63 Velocity_63 Duration_1.3.8 Pitch_70 Velocity_71 Duration_0.2.8 Pitch_66 Velocity_67 Duration_0.3.8 Position_16 Pitch_70 Velocity_83 Duration_0.2.8 Position_23 Pitch_59 Velocity_51 Duration_1.1.8 Pitch_81 Velocity_79 Duration_1.5.8 Pitch_75 Velocity_71 Duration_1.5.8 Position_24 Pitch_74 Velocity_63 Duration_1.2.8 Position_30 Pitch_54 Velocity_63 Duration_0.3.8 Bar_None Position_0 Pitch_73 Velocity_71 Duration_0.1.8 Position_3 Pitch_65 Velocity_67 Duration_0.5.8 Pitch_73 Velocity_83 Duration_0.4.8 Position_8 Pitch_82 Velocity_91 Duration_0.7.8 Position_13 Pitch_66 Velocity_59 Duration_0.5.8 Pitch_70 Velocity_67 Duration_0.4.8 Pitch_78 Velocity_87 Duration_0.4.8 Position_18 Pitch_74 Velocity_83 Duration_0.5.8 Position_19 Pitch_67 Velocity_59 Duration_0.1.8 Position_20 Pitch_71 Velocity_59 Duration_0.1.8 Position_23 Pitch_85 Velocity_87 Duration_0.6.8 Position_24 Pitch_71 Velocity_71 Duration_0.4.8 Pitch_67 Velocity_75 Duration_0.4.8 Position_28 Pitch_81 Velocity_71 Duration_0.3.8 Position_29 Pitch_68 Velocity_75 Duration_0.1.8 Pitch_72 Velocity_71 Duration_0.1.8 Bar_None Position_0 Pitch_72 Velocity_59 Duration_0.4.8 Pitch_68 Velocity_79 Duration_0.3.8 Pitch_77 Velocity_83 Duration_0.3.8 Position_4 Pitch_81 Velocity_87 Duration_1.0.8 Position_5 Pitch_73 Velocity_67 Duration_0.1.8 Position_6 Pitch_69 Velocity_63 Duration_0.1.8 Position_9 Pitch_69 Velocity_75 Duration_0.2.8 Pitch_73 Velocity_75 Duration_0.2.8 Position_11 Pitch_75 Velocity_95 Duration_0.7.8 Position_16 Pitch_71 Velocity_67 Duration_0.1.8 Pitch_67 Velocity_71 Duration_0.1.8 P ...

# %%
metadata_df
# Out:
#            canonical_composer                 canonical_title       split  \
# 0                  Alban Berg                    Sonata Op. 1       train
# 1                  Alban Berg                    Sonata Op. 1       train
# 2                  Alban Berg                    Sonata Op. 1       train
# 3          Alexander Scriabin   24 Preludes Op. 11, No. 13-24       train
# 4          Alexander Scriabin                3 Etudes, Op. 65  validation
# ...                       ...                             ...         ...
# 1271  Wolfgang Amadeus Mozart         Sonata in F Major, K280        test
# 1272  Wolfgang Amadeus Mozart         Sonata in F Major, K280       train
# 1273  Wolfgang Amadeus Mozart         Sonata in F Major, K533  validation
# 1274  Wolfgang Amadeus Mozart    Sonata in F Major, K533/K494  validation
# 1275  Wolfgang Amadeus Mozart  Twelve Variations, K179 (189a)       train
#
#       year                                      midi_filename  \
# 0     2018  2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...
# 1     2008  2008/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MI...
# 2     2017  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...
# 3     2004  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...
# 4     2006  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...
# ...    ...                                                ...
# 1271  2004  2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MI...
# 1272  2004  2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MI...
# 1273  2004  2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORI...
# 1274  2018  2018/MIDI-Unprocessed_Recital17-19_MID--AUDIO_...
# 1275  2004  2004/MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG...
#
#                                          audio_filename     duration  \
# 0     2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...   698.661160
# 1     2008/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MI...   759.518471
# 2     2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...   464.649433
# 3     2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...   872.640588
# 4     2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...   397.857508
# ...                                                 ...          ...
# 1271  2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MI...   241.470442
# 1272  2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MI...   114.696243
# 1273  2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORI...  1139.198478
# 1274  2018/MIDI-Unprocessed_Recital17-19_MID--AUDIO_...  1068.751602
# 1275  2004/MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG...   630.266303
#
#                                                filename
# 0     MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_201...
# 1     MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MID--AU...
# 2     MIDI-Unprocessed_066_PIANO066_MID--AUDIO-split...
# 3     MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MID--AU...
# 4     MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AU...
# ...                                                 ...
# 1271  MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AU...
# 1272  MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AU...
# 1273  MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID...
# 1274  MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1...
# 1275  MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG_MID-...
#
# [1276 rows x 8 columns]

# %%
import os
import pandas as pd
import miditok
import miditoolkit
from tqdm import tqdm

# Initialize MIDI tokenizer
midi_tokenizer = miditok.REMI()  # Use your preferred MIDI tokenizer


def process_midi_from_metadata(metadata_df, get_midi_path, output_folder):
    """
    Iterates through the metadata DataFrame, converts MIDI files to text, and saves them.

    Args:
        metadata_df (pd.DataFrame): DataFrame containing metadata about MIDI files.
        get_midi_path (function): Function to retrieve the MIDI file path by index.
        output_folder (str): Directory to save processed text files.

    Returns:
        None
    """
    os.makedirs(output_folder, exist_ok=True)

    for index, row in tqdm(metadata_df.iterrows(), total=len(metadata_df)):
        try:
            # Get MIDI file path
            midi_path = get_midi_path(index)

            # Extract metadata
            composer = row.get("canonical_composer", "Unknown")
            piece_type = row.get("canonical_title", "Unknown")

            # Convert MIDI to structured text
            text_data = midi_to_text(midi_path, composer, piece_type)

            if text_data:
                # Save text data as a .txt file
                output_file = os.path.join(output_folder, os.path.basename(midi_path).replace(".midi", ".txt"))
                with open(output_file, "w") as f:
                    f.write(text_data)

        except Exception as e:
            print(f"Error processing row {index}: {e}")

    print("✅ All MIDI files processed and saved as text.")


output_text_folder = "/content/maestro_text"  # Define output directory

# Run the processing script
process_midi_from_metadata(metadata_df, get_midi_path, output_text_folder)
# Out:
# 100%|██████████| 1276/1276 [03:22<00:00,  6.29it/s]
# ✅ All MIDI files processed and saved as text.

# %%
## Lets Load the Data

# %% [markdown]
# Sofar the MIDI files are converted to text files
#
# GPT2 tokenizer is able to parse these midis and tokenize  them

# %%
import os

import glob

def find_txt_files(folder_path):
    txt_files = []
    for filename in glob.glob(os.path.join(folder_path, '*.txt')):
        txt_files.append(filename)
    return txt_files

folder_path = "/content/maestro_text"
txt_files = find_txt_files(folder_path)

# %%
assert len(metadata_df) == len(txt_files)

# %%
# look at one of the files beginnig :

file_path = txt_files [0]

with open(file_path , 'r') as file :
  for i in range(10):
    line= file.readline()
    if not line : # stopping if file is less than 10 lines
      break
    print(line)
# Out:
# <COMPOSER> Claude Debussy <PIECE_TYPE> "Ondine" from Book II <BOS> Bar_None Position_16 Pitch_61 Velocity_35 Duration_0.4.8 Position_23 Pitch_70 Velocity_43 Duration_0.1.8 Pitch_69 Velocity_35 Duration_0.1.8 Position_24 Pitch_67 Velocity_27 Duration_0.1.8 Position_30 Pitch_73 Velocity_51 Duration_0.5.8 Pitch_77 Velocity_51 Duration_0.4.8 Bar_None Position_8 Pitch_70 Velocity_43 Duration_0.3.8 Position_9 Pitch_69 Velocity_39 Duration_0.2.8 Pitch_67 Velocity_39 Duration_0.2.8 Position_14 Pitch_61 Velocity_43 Duration_0.6.8 Position_25 Pitch_67 Velocity_35 Duration_0.1.8 Pitch_69 Velocity_35 Duration_0.1.8 Pitch_71 Velocity_31 Duration_0.1.8 Bar_None Position_0 Pitch_78 Velocity_51 Duration_0.5.8 Pitch_73 Velocity_51 Duration_0.5.8 Position_13 Pitch_67 Velocity_35 Duration_0.4.8 Pitch_69 Velocity_31 Duration_0.5.8 Pitch_71 Velocity_39 Duration_0.4.8 Position_21 Pitch_61 Velocity_47 Duration_1.1.8 Bar_None Position_16 Pitch_33 Velocity_47 Duration_1.0.8 Position_27 Pitch_59 Velocity_35 Duration_0.5.8 Pitch_57 Velocity_27 Duration_0.4.8 Pitch_55 Velocity_27 Duration_0.3.8 Bar_None Position_1 Pitch_66 Velocity_43 Duration_0.2.8 Pitch_61 Velocity_43 Duration_0.2.8 Position_7 Pitch_69 Velocity_35 Duration_0.3.8 Pitch_71 Velocity_39 Duration_0.3.8 Pitch_67 Velocity_39 Duration_0.2.8 Position_13 Pitch_73 Velocity_35 Duration_0.2.8 Pitch_78 Velocity_31 Duration_0.3.8 Position_20 Pitch_83 Velocity_35 Duration_3.5.8 Pitch_81 Velocity_35 Duration_3.5.8 Pitch_79 Velocity_35 Duration_3.4.8 Position_30 Pitch_85 Velocity_47 Duration_0.2.8 Position_31 Pitch_90 Velocity_39 Duration_0.2.8 Bar_None Bar_None Position_4 Pitch_68 Velocity_79 Duration_0.1.8 Pitch_62 Velocity_67 Duration_0.1.8 Pitch_73 Velocity_79 Duration_0.1.8 Pitch_74 Velocity_75 Duration_0.1.8 Pitch_80 Velocity_79 Duration_0.2.8 Position_5 Pitch_85 Velocity_75 Duration_0.1.8 Position_6 Pitch_82 Velocity_75 Duration_0.2.8 Position_7 Pitch_70 Velocity_91 Duration_0.1.8 Position_9 Pitch_70 Velocity_87 Duration_0.1.8 Pitch_69 Velocity_91 Duration_0.1.8 Pitch_64 Velocity_51 Duration_0.2.8 Pitch_58 Velocity_59 Duration_0.1.8 Pitch_76 Velocity_83 Duration_0.2.8 Position_10 Pitch_81 Velocity_79 Duration_0.1.8 Pitch_83 Velocity_83 Duration_0.1.8 Pitch_82 Velocity_63 Duration_0.1.8 Bar_None Position_3 Pitch_33 Velocity_43 Duration_0.7.8 Position_14 Pitch_59 Velocity_39 Duration_0.3.8 Pitch_57 Velocity_27 Duration_0.3.8 Pitch_55 Velocity_23 Duration_0.2.8 Position_20 Pitch_66 Velocity_35 Duration_0.2.8 Pitch_61 Velocity_27 Duration_0.2.8 Position_26 Pitch_71 Velocity_43 Duration_0.3.8 Pitch_67 Velocity_27 Duration_0.1.8 Pitch_69 Velocity_39 Duration_0.2.8 Position_31 Pitch_78 Velocity_43 Duration_0.3.8 Bar_None Position_0 Pitch_73 Velocity_43 Duration_0.2.8 Position_6 Pitch_83 Velocity_39 Duration_0.3.8 Pitch_81 Velocity_35 Duration_0.3.8 Pitch_79 Velocity_27 Duration_0.2.8 Position_16 Pitch_90 Velocity_35 Duration_0.3.8 Pitch_85 Velocity_43 Duration_0.4.8 Bar_None Position_18 Pitch_74 Velocity_71 Duration_0.1.8 Pitch_68 Velocity_87 Duration_0.1.8 Pitch_62 Velocity_67 Duration_0.1.8 Pitch_73 Velocity_79 Duration_0.1.8 Position_19 Pitch_80 Velocity_75 Duration_0.2.8 Position_20 Pitch_85 Velocity_71 Duration_0.1.8 Pitch_82 Velocity_75 Duration_0.2.8 Position_21 Pitch_70 Velocity_91 Duration_0.1.8 Position_22 Pitch_71 Velocity_75 Duration_0.1.8 Pitch_72 Velocity_31 Duration_0.1.8 Position_23 Pitch_70 Velocity_83 Duration_0.1.8 Pitch_76 Velocity_51 Duration_0.2.8 Position_24 Pitch_64 Velocity_59 Duration_0.2.8 Pitch_69 Velocity_87 Duration_0.1.8 Pitch_58 Velocity_67 Duration_0.1.8 Position_25 Pitch_81 Velocity_99 Duration_0.1.8 Bar_None Position_9 Pitch_55 Velocity_63 Duration_0.1.8 Pitch_61 Velocity_71 Duration_0.1.8 Pitch_66 Velocity_67 Duration_0.1.8 Position_10 Pitch_67 Velocity_67 Duration_0.1.8 Pitch_73 Velocity_63 Duration_0.1.8 Position_11 Pitch_78 Velocity_67 Duration_0.2.8 Position_12 Pitch_75 Velocity_71 Duration_0.2.8 Pitch_63 Velocity_79 Duration_0.1.8 Position_13 Pitch_58 Velocity_51 ...

# %%
raw_datasets = load_dataset("text", data_files=txt_files)
raw_datasets
# Out:
# Resolving data files:   0%|          | 0/1276 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/1276 [00:00<?, ?files/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 1276
#     })
# })

# %%
## Lets bring the model and start training

# %%
# tokenizer is preloaded and extended :
gpt_tokenizer

#model is preloaded and extended with new tokens
model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50539, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50539, bias=False)
# )

# %%
token_sequence = raw_datasets["train"][3]["text"]

print(token_sequence)

indices = gpt_tokenizer(token_sequence)["input_ids"]
print('indices : ')
print(indices)

tokens = [gpt_tokenizer.decode([index]) for index in indices]
print(tokens)
print(len(tokens))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model
# ['<', 'COM', 'POS', 'ER', '>', ' Johann', ' Sebastian', ' Bach', ' <', 'PI', 'EC', 'E', '_', 'TYPE', '>', ' Prelude', ' and', ' Fug', 'ue', ' in', ' A', '-', 'flat', ' Major', ',', ' WTC', ' I', ' <', 'B', 'OS', '>', ' ', 'Bar_None', ' ', 'Position_17', ' ', 'Pitch_56', ' ', 'Velocity_67', ' ', 'Duration_0.3.8', ' ', 'Pitch_63', ' ', 'Velocity_91', ' ', 'Duration_0.3.8', ' ', 'Pitch_60', ' ', 'Velocity_67', ' ', 'Duration_0.3.8', ' ', 'Position_23', ' ', 'Pitch_68', ' ', 'Velocity_83', ' ', 'Duration_0.2.8', ' ', 'Position_25', ' ', 'Pitch_67', ' ', 'Velocity_91', ' ', 'Duration_0.2.8', ' ', 'Position_27', ' ', 'Pitch_68', ' ', 'Velocity_71', ' ', 'Duration_0.1.8', ' ', 'Bar_None', ' ', 'Position_0', ' ', 'Pitch_72', ' ', 'Velocity_71', ' ', 'Duration_0.1.8', ' ', 'Position_4', ' ', 'Pitch_63', ' ', 'Velocity_75', ' ', 'Duration_0.2.8', ' ', 'Position_9', ' ', 'Pitch_68', ' ', 'Velocity_79', ' ', 'Duration_0.1.8', ' ', 'Position_14', ' ', 'Pitch_63', ' ', 'Velocity_95', ' ', 'Duration_0.5.8', ' ', 'Pitch_55', ' ', 'Velocity_79', ' ', 'Duration_0.5.8', ' ', 'Pitch_58', ' ', 'Velocity_75', ' ', 'Duration_0.5.8', ' ', 'Position_19', ' ', 'Pitch_70', ' ', 'Velocity_83', ' ', 'Duration_0.2.8', ' ', 'Position_20', ' ', 'Pitch_68', ' ', 'Velocity_91', ' ', 'Duration_0.2.8', ' ', 'Position_22', ' ', 'Pitch_70', ' ', 'Velocity_87', ' ', 'Duration_0.1.8', ' ', 'Position_27', ' ', 'Pitch_73', ' ', 'Velocity_79', ' ', 'Duration_0.1.8', ' ', 'Position_31', ' ', 'Pitch_63', ' ', 'Velocity_67', ' ', 'Duration_0.1.8', ' ', 'Bar_None', ' ', 'Position_3', ' ', 'Pitch_70', ' ', 'Velocity_71', ' ', 'Duration_0.1.8', ' ', 'Position_8', ' ', 'Pitch_72', ' ', 'Velocity_75', ' ', 'Duration_0.1.8', ' ', 'Position_13', ' ', 'Pitch_56', ' ', 'Velocity_71', ' ', 'Duration_0.2.8', ' ', 'Position_14', ' ', 'Pitch_55', ' ', 'Velocity_67', ' ', 'Duration_0.2.8', ' ', 'Position_16', ' ', 'Pitch_75', ' ', 'Velocity_59', ' ', 'Duration_0.5.8', ' ', 'Pitch_56', ' ', 'Velocity_67', ' ', 'Duration_0.1.8', ' ', 'Pitch_80', ' ', 'Velocity_95', ' ', 'Duration_1.5.8', ' ', 'Position_17', ' ', 'Pitch_72', ' ', 'Velocity_75', ' ', 'Duration_1.1.8', ' ', 'Position_21', ' ', 'Pitch_60', ' ', 'Velocity_59', ' ', 'Duration_0.1.8', ' ', 'Position_26', ' ', 'Pitch_51', ' ', 'Velocity_67', ' ', 'Duration_0.1.8', ' ', 'Position_30', ' ', 'Pitch_75', ' ', 'Velocity_79', ' ', 'Duration_0.1.8', ' ', 'Pitch_56', ' ', 'Velocity_63', ' ', 'Duration_0.1.8', ' ', 'Pitch_72', ' ', 'Velocity_67', ' ', 'Duration_0.1.8', ' ', 'Bar_None', ' ', 'Position_2', ' ', 'Pitch_73', ' ', 'Velocity_83', ' ', 'Duration_0.1.8', ' ', 'Pitch_70', ' ', 'Velocity_83', ' ', 'Duration_0.1.8', ' ', 'Position_7', ' ', 'Pitch_58', ' ', 'Velocity_75', ' ', 'Duration_0.2.8', ' ', 'Position_9', ' ', 'Pitch_56', ' ', 'Velocity_75', ' ', 'Duration_0.2.8', ' ', 'Position_11', ' ', 'Pitch_58', ' ', 'Velocity_75', ' ', 'Duration_0.1.8', ' ', 'Pitch_79', ' ', 'Velocity_95', ' ', 'Duration_1.3.8', ' ', 'Position_16', ' ', 'Pitch_61', ' ', 'Velocity_71', ' ', 'Duration_0.1.8', ' ', 'Position_20', ' ', 'Pitch_51', ' ', 'Velocity_67', ' ', 'Duration_0.1.8', ' ', 'Position_25', ' ', 'Pitch_79', ' ', 'Velocity_79', ' ', 'Duration_0.1.8', ' ', 'Pitch_58', ' ', 'Velocity_67', ' ', 'Duration_0.1.8', ' ', 'Pitch_70', ' ', 'Velocity_67', ' ', 'Duration_0.1.8', ' ', 'Pitch_73', ' ', 'Velocity_35', ' ', 'Duration_0.1.8', ' ', 'Position_29', ' ', 'Pitch_80', ' ', 'Velocity_95', ' ', 'Duration_0.1.8', ' ', 'Position_30', ' ', 'Pitch_68', ' ', 'Velocity_83', ' ', 'Duration_0.1.8', ' ', 'Pitch_75', ' ', 'Velocity_71', ' ', 'Duration_0.1.8', ' ', 'Bar_None', ' ', 'Position_2', ' ', 'Pitch_60', ' ', 'Velocity_71', ' ', 'Duration_0.2.8', ' ', 'Position_4', ' ', 'Pitch_58', ' ', 'Velocity_71', ' ', 'Duration_0.2.8', ' ', 'Position_6', ' ', 'Pitch_75', ' ', 'Velocity_99', ' ', 'Duration_1.4.8', ' ', 'Pitch_60', ' ', 'Velocity_63', ' ', 'Duration_0.1.8', ' ', 'Position_11', ' ', 'Pitch_63', ' ', 'Velocity_63', ' ', 'Duration_0.1.8', ' ', 'Pos ...
# 11665

# %% [markdown]
# ** The indices sequence length is longer for the model **
#
# we can have two approaches to combat this ,
#
# 1. Truncate (by giving a max sequence length of 1024 )
# 2. chunking with overlap

# %%
# def chunk_long_sequences(examples):
#     tokenized_text = hf_tokenizer(examples["text"])["input_ids"]

#     # Split into overlapping chunks of max 1024 tokens
#     chunk_size = 1024
#     overlap = 256  # 25% overlap for better continuity
#     chunks = [tokenized_text[i : i + chunk_size] for i in range(0, len(tokenized_text), chunk_size - overlap)]

#     return {"input_ids": chunks}

# tokenized_datasets = raw_datasets.map(chunk_long_sequences, batched=False)

# %%
import matplotlib.pylab as plt
import tqdm

lengths = []
for token_sequence in tqdm.tqdm(raw_datasets["train"]):
    token_sequence = token_sequence["text"]
    indices = gpt_tokenizer(token_sequence)["input_ids"]
    lengths += [len(indices)]

plt.hist(lengths, bins=50)
plt.show()
# Out:
# 100%|██████████| 1276/1276 [03:35<00:00,  5.92it/s]

# %% [markdown]
# # Train the model

# %%
# tokenizing function

sequence_length = 256

def tokenize_function(example):
    tokenized_example = gpt_tokenizer(
        example["text"],
        truncation=True,
        padding=True,
        max_length=sequence_length,
    )
    return {
        "input_ids": tokenized_example["input_ids"]
    }

# Check a sample.
token_sequence = raw_datasets["train"][0]
print(token_sequence)
tokenized = tokenize_function(token_sequence)
assert list(tokenized.keys()) == ["input_ids"], list(tokenized.keys())
print(tokenized)
# Out:
# {'text': '<COMPOSER> Claude Debussy <PIECE_TYPE> "Ondine" from Book II <BOS> Bar_None Position_16 Pitch_61 Velocity_35 Duration_0.4.8 Position_23 Pitch_70 Velocity_43 Duration_0.1.8 Pitch_69 Velocity_35 Duration_0.1.8 Position_24 Pitch_67 Velocity_27 Duration_0.1.8 Position_30 Pitch_73 Velocity_51 Duration_0.5.8 Pitch_77 Velocity_51 Duration_0.4.8 Bar_None Position_8 Pitch_70 Velocity_43 Duration_0.3.8 Position_9 Pitch_69 Velocity_39 Duration_0.2.8 Pitch_67 Velocity_39 Duration_0.2.8 Position_14 Pitch_61 Velocity_43 Duration_0.6.8 Position_25 Pitch_67 Velocity_35 Duration_0.1.8 Pitch_69 Velocity_35 Duration_0.1.8 Pitch_71 Velocity_31 Duration_0.1.8 Bar_None Position_0 Pitch_78 Velocity_51 Duration_0.5.8 Pitch_73 Velocity_51 Duration_0.5.8 Position_13 Pitch_67 Velocity_35 Duration_0.4.8 Pitch_69 Velocity_31 Duration_0.5.8 Pitch_71 Velocity_39 Duration_0.4.8 Position_21 Pitch_61 Velocity_47 Duration_1.1.8 Bar_None Position_16 Pitch_33 Velocity_47 Duration_1.0.8 Position_27 Pitch_59 Velocity_35 Duration_0.5.8 Pitch_57 Velocity_27 Duration_0.4.8 Pitch_55 Velocity_27 Duration_0.3.8 Bar_None Position_1 Pitch_66 Velocity_43 Duration_0.2.8 Pitch_61 Velocity_43 Duration_0.2.8 Position_7 Pitch_69 Velocity_35 Duration_0.3.8 Pitch_71 Velocity_39 Duration_0.3.8 Pitch_67 Velocity_39 Duration_0.2.8 Position_13 Pitch_73 Velocity_35 Duration_0.2.8 Pitch_78 Velocity_31 Duration_0.3.8 Position_20 Pitch_83 Velocity_35 Duration_3.5.8 Pitch_81 Velocity_35 Duration_3.5.8 Pitch_79 Velocity_35 Duration_3.4.8 Position_30 Pitch_85 Velocity_47 Duration_0.2.8 
383, 220, 50313, 220, 50358, 220, 50383, 220, 50262, 220, 50447, 220, 50320, 220, 50363, 220, 50387, 220, 50315, 220, 50363, 220, 50387, 220, 50460, 220, 50309, 220, 50359, 220, 50386, 220, 50311, 220, 50358, 220, 50387, 220, 50313, 220, 50360, 220, 50386, 220, 50468, 220, 50303, 220, 50362, 220, 50391, 220, 50262, 220, 50463, 220, 50275, 220, 50362, 220, 50390, 220, 50474, 220, 50301, 220, 50359, 220, 50387, 220, 50299, 220, 50357, 220, 50386, 220, 50297, 220, 50357, 220, 50385, 220, 50262, 220, 50448, 220, 50308, 220, 50361, 220, 50384, 220, 50303, 220, 50361, 220, 50384, 220, 50454, 220, 50311, 220, 50359, 220, 50385, 220, 50313, 220, 50360, 220, 50385, 220, 50309, 220, 50360, 220, 50384, 220, 50460, 220, 50315, 220, 50359, 220, 50384, 220, 50320, 220, 50358, 220, 50385, 220, 50467, 220, 50325, 220, 50359, 220]}

# %%
from transformers import DataCollatorForLanguageModeling
import torch

# %%
#initiate a data collector

data_collator = DataCollatorForLanguageModeling(gpt_tokenizer, mlm=False)

# %%
# Test data collector and mode

# %%
inputs = [tokenized_datasets["train"][2]]
inputs = data_collator(inputs)
assert list(inputs.keys()) == ["input_ids", "attention_mask", "labels"], list(inputs.keys())
print("input_ids:", inputs["input_ids"])
print("")

outputs = model(**inputs)
assert list(outputs.keys()) == ["loss", "logits", "past_key_values"], list(outputs.keys())
print("logits:", outputs["logits"])

plt.plot(outputs["logits"].detach().numpy()[0][0])
plt.title("Logits")
plt.show()
plt.close()

activations = torch.nn.functional.softmax(outputs["logits"], dim=-1)
plt.plot(activations.detach().numpy()[0][0])
plt.title("Activations")
plt.show()
plt.close()
# Out:
# input_ids: tensor([[   27,  9858, 37997,  1137,    29,  7212,  9075, 32656,  1279, 11901,
#           2943,    36,    62, 25216,    29,  6295,  1045,   287,   376,  8386,
#             11, 17073,    13, 49090,    25,  1954,  1279,    33,  2640,    29,
#            220, 50262,   220, 50463,   220, 50314,   220, 50367,   220, 50387,
#            220, 50468,   220, 50311,   220, 50365,   220, 50383,   220, 50469,
#            220, 50307,   220, 50367,   220, 50383,   220, 50470,   220, 50295,
#            220, 50361,   220, 50383,   220, 50299,   220, 50362,   220, 50383,
#            220, 50476,   220, 50311,   220, 50368,   220, 50387,   220, 50262,
#            220, 50449,   220, 50307,   220, 50365,   220, 50383,   220, 50451,
#            220, 50306,   220, 50367,   220, 50383,   220, 50290,   220, 50364,
#            220, 50383,   220, 50300,   220, 50363,   220, 50383,   220, 50458,
#            220, 50309,   220, 50366,   220, 50387,   220, 50463,   220, 50306,
#            220, 50364,   220, 50383,   220, 50464,   220, 50307,   220, 50365,
#            220, 50383,   220, 50295,   220, 50361,   220, 50383,   220, 50299,
#            220, 50361,   220, 50383,   220, 50472,   220, 50316,   220, 50367,
#            220, 50390,   220, 50312,   220, 50363,   220, 50389,   220, 50262,
#            220, 50447,   220, 50314,   220, 50365,   220, 50386,   220, 50311,
#            220, 50363,   220, 50385,   220, 50455,   220, 50321,   220, 50366,
#            220, 50385,   220, 50456,   220, 50319,   220, 50368,   220, 50384,
#            220, 50458,   220, 50318,   220, 50369,   220, 50384,   220, 50460,
#            220, 50316,   220, 50369,   220, 50384,   220, 50462,   220, 50314,
#            220, 50370,   220, 50389,   220, 50466,   220, 50307,   220, 50361,
#            220, 50391,   220, 50469,   220, 50323,   220, 50370,   220, 50384,
#            220, 50471,   220, 50311,   220, 50369,   220, 50384,   220, 50472,
#            220, 50316,   220, 50370,   220, 50385,   220, 50475,   220, 50314,
#            220, 50371,   220, 50388,   220, 50476]])
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# logits: tensor([[[ -31.7897,  -30.7168,  -32.1723,  ...,  -37.7648,  -37.7648,
#            -37.7648],
#          [ -79.9904,  -78.5193,  -82.4451,  ...,  -89.0597,  -89.0597,
#            -89.0597],
#          [ -68.7425,  -69.5335,  -71.4340,  ...,  -80.0685,  -80.0685,
#            -80.0685],
#          ...,
#          [   7.2668,    6.2057,    5.0321,  ...,    0.4878,    0.4878,
#              0.4878],
#          [-148.4430, -153.2144, -153.1340,  ..., -157.1273, -157.1273,
#           -157.1273],
#          [   7.5779,    6.5261,    5.3375,  ...,    0.7953,    0.7953,
#              0.7953]]], grad_fn=<UnsafeViewBackward0>)

# %%
from transformers import GPT2Config, GPT2LMHeadModel
from transformers import TrainingArguments, Trainer

# %%
# Get the output directory with timestamp.
output_path = "output"

# Create the trainer.
print("Creating trainer...")
training_args = TrainingArguments(
    output_dir=output_path,
    overwrite_output_dir=True,
    num_train_epochs=2,
    per_device_train_batch_size=72,
    prediction_loss_only=False,
    #report_to="none"
)
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=tokenized_datasets["train"],
)

# Train the model.
trainer.train()

# Save the tokenizer.
tokenizer.save_pretrained(output_path)

# Save the model.
model.save_pretrained(output_path)
# Out:
# Creating trainer...
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# ---------------------------------------------------------------------------
# Abort                                     Traceback (most recent call last)
# <ipython-input-55-3c764beea986> in <cell line: 0>()
#      20
#      21 # Train the model.
# ---> 22 trainer.train()
#      23
#      24 # Save the tokenizer.
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2169                 hf_hub_utils.enable_progress_bars()
#    2170         else:
# -> 2171             return inner_training_loop(
#    2172                 args=args,
#    2173                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2435         model.zero_grad()
#    2436         grad_norm: Optional[float] = None
# -> 2437         self.control = self.callback_handler.on_train_begin(args, self.state, self.control)
#    2438
#    2439         if args.eval_on_start:
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer_callback.py in on_train_begin(self, args, state, control)
#     467     def on_train_begin(self, args: TrainingArguments, state: TrainerState, control: TrainerControl):
#     468         control.should_training_stop = False
# --> 469         return self.call_event("on_train_begin", args, state, control)
#     470
#     471     def on_train_end(self, args: TrainingArguments, state: TrainerState, control: TrainerControl):
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer_callback.py in call_event(self, event, args, state, control, **kwargs)
#     517     def call_event(self, event, args, state, control, **kwargs):
#     518         for callback in self.callbacks:
# --> 519             result = getattr(callback, event)(
#     520                 args,
#     521                 state,
#
# /usr/local/lib/python3.11/dist-packages/transformers/integrations/integration_utils.py in on_train_begin(self, args, state, control, model, **kwargs)
#     914             args.run_name = None
#     915         if not self._initialized:
# --> 916             self.setup(args, state, model, **kwargs)
#     917
#     918     def on_train_end(self, args, state, control, model=None, tokenizer=None, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/transformers/integrations/integration_utils.py in setup(self, args, state, model, **kwargs)
#     841
#     842             if self._wandb.run is None:
# --> 843                 self._wandb.init(
#     844                     project=os.getenv("WANDB_PROJECT", "huggingface"),
#     845                     **init_args,
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_init.py in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, anonymous, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings)
#    1483         # Need to build delay into this sentry capture because our exit hooks
#    1484         # mess with sentry's ability to send out errors before the program ends.
# -> 1485         wandb._sentry.reraise(e)
#    1486         raise AssertionError()  # should never get here
#
# /usr/local/lib/python3.11/dist-packages/wandb/analytics/sentry.py in reraise(self, exc)
#     154         # this will messily add this "reraise" function to the stack trace,
#     155         # but hopefully it's not too bad
# --> 156         raise exc.with_traceback(sys.exc_info()[2])
#     157
#     158     @_safe_noop
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_init.py in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, anonymous, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings)
#    1431         wi = _WandbInit(wl, init_telemetry)
#    1432
# -> 1433         wi.maybe_login(init_settings)
#    1434         run_settings = wi.make_run_settings(init_settings)
#    1435
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_init.py in maybe_login(self, init_settings)
#     173             return
#     174
# --> 175         wandb_login._login(
#     176             anonymous=run_settings.anonymous,
#     177             force=run_settings.force,
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_login.py in _login(anonymous, key, relogin, host, force, timeout, verify, _silent, _disable_warning)
#     300             key_is_pre_configured = True
#     301         else:
# --> 302             key, key_status = wlogin.prompt_api_key()
#     303
#     304     if verify:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_login.py in prompt_api_key(self)
#     222     def prompt_api_key(self) -> Tuple[Optional[str], ApiKeyStatus]:
#     223         """Updates the global API key by prompting the user."""
# --> 224         key, status = self._prompt_api_key()
#     225         if status == ApiKeyStatus.NOTTY:
#     226             directive = (
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_login.py in _prompt_api_key(self)
#     201         while True:
#     202             try:
# --> 203                 key = apikey.prompt_api_key(
#     204                     self._settings,
#     205                     api=api,
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/apikey.py in prompt_api_key(settings, api, input_callback, browser_callback, no_offline, no_create, local)
#     153                 f"You can find your API key in your browser here: {app_url}/authorize"
#     154             )
# --> 155             key = input_callback(api_ask).strip()
#     156     elif result == LOGIN_CHOICE_NOTTY:
#     157         # TODO: Needs refactor as this needs to be handled by caller
#
# /usr/local/lib/python3.11/dist-packages/click/termui.py in prompt(text, default, hide_input, confirmation_prompt, type, value_proc, prompt_suffix, show_default, err, show_choices)
#     162     while True:
#     163         while True:
# --> 164             value = prompt_func(prompt)
#     165             if value:
#     166                 break
#
# /usr/local/lib/python3.11/dist-packages/click/termui.py in prompt_func(text)
#     145             if hide_input:
#     146                 echo(None, err=err)
# --> 147             raise Abort() from None
#     148
#     149     if value_proc is None:
#
# Abort:
